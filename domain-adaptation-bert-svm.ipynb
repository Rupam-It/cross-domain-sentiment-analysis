# %%
import pandas as pd
import re
import torch
from transformers import BertTokenizer, BertModel, BertForSequenceClassification, AdamW, get_scheduler
from sklearn.model_selection import train_test_split
from torch.utils.data import DataLoader, TensorDataset

# Load and clean the dataset
train_file_path = '/kaggle/input/sentiment-analysis/DVD11.csv'  # Use your domain-specific file
train_data = pd.read_csv(train_file_path, nrows=20000)

# Clean text data
def clean_text(text):
    if isinstance(text, str):
        text = text.lower()
        text = re.sub(r'\s+', ' ', text)
        text = re.sub(r'[^\w\s]', '', text)
        return text
    return None

train_data['cleaned_review'] = train_data['review_body'].apply(clean_text)
train_data = train_data.dropna(subset=['cleaned_review'])

# Initialize BERT tokenizer
bert_tokenizer = BertTokenizer.from_pretrained('bert-large-cased')

# Tokenize and encode data
max_length = 128

def encode_review_bert(text):
    return bert_tokenizer.encode_plus(
        text,
        add_special_tokens=True,
        max_length=max_length,
        padding='max_length',
        truncation=True,
        return_attention_mask=True,
        return_tensors='pt'
    )

input_ids = []
attention_masks = []

for review in train_data['cleaned_review']:
    encoded_review = encode_review_bert(review)
    input_ids.append(encoded_review['input_ids'])
    attention_masks.append(encoded_review['attention_mask'])

# Convert lists to tensors
input_ids = torch.cat(input_ids, dim=0)
attention_masks = torch.cat(attention_masks, dim=0)
labels = torch.tensor(train_data['star_rating'].values)

# Split data into training and validation sets
train_inputs, val_inputs, train_masks, val_masks, train_labels, val_labels = train_test_split(
    input_ids, attention_masks, labels, test_size=0.1, random_state=42
)

# Create DataLoader
batch_size = 16
train_data = TensorDataset(train_inputs, train_masks, train_labels)
train_dataloader = DataLoader(train_data, batch_size=batch_size, shuffle=True)

val_data = TensorDataset(val_inputs, val_masks, val_labels)
val_dataloader = DataLoader(val_data, batch_size=batch_size)
# Out:
# tokenizer_config.json:   0%|          | 0.00/49.0 [00:00<?, ?B/s]
# vocab.txt:   0%|          | 0.00/213k [00:00<?, ?B/s]
# tokenizer.json:   0%|          | 0.00/436k [00:00<?, ?B/s]
# config.json:   0%|          | 0.00/762 [00:00<?, ?B/s]
# /opt/conda/lib/python3.10/site-packages/transformers/tokenization_utils_base.py:1601: FutureWarning: `clean_up_tokenization_spaces` was not set. It will be set to `True` by default. This behavior will be depracted in transformers v4.45, and will be then set to `False` by default. For more details check this issue: https://github.com/huggingface/transformers/issues/31884
#   warnings.warn(

# %%
# Load pre-trained BERT for sequence classification
bert_model = BertForSequenceClassification.from_pretrained('bert-large-cased', num_labels=5)
device = torch.device('cuda') if torch.cuda.is_available() else torch.device('cpu')
bert_model.to(device)

# Define optimizer and scheduler
optimizer = AdamW(bert_model.parameters(), lr=2e-5)
epochs = 3
num_training_steps = epochs * len(train_dataloader)
lr_scheduler = get_scheduler(
    name="linear",
    optimizer=optimizer,
    num_warmup_steps=0,
    num_training_steps=num_training_steps
)

# Fine-tuning loop
from tqdm.auto import tqdm

progress_bar = tqdm(range(num_training_steps))
bert_model.train()

for epoch in range(epochs):
    for batch in train_dataloader:
        batch_input_ids, batch_masks, batch_labels = [b.to(device) for b in batch]
        outputs = bert_model(batch_input_ids, attention_mask=batch_masks, labels=batch_labels)
        loss = outputs.loss
        loss.backward()
        optimizer.step()
        lr_scheduler.step()
        optimizer.zero_grad()
        progress_bar.update(1)

    print(f"Epoch {epoch+1}/{epochs} completed. Loss: {loss.item()}")

# Save the fine-tuned BERT model
bert_model.save_pretrained('./fine_tuned_bert_model')
bert_tokenizer.save_pretrained('./fine_tuned_bert_model')
# Out:
# model.safetensors:   0%|          | 0.00/1.34G [00:00<?, ?B/s]
# Some weights of BertForSequenceClassification were not initialized from the model checkpoint at bert-large-cased and are newly initialized: ['classifier.bias', 'classifier.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# /opt/conda/lib/python3.10/site-packages/transformers/optimization.py:591: FutureWarning: This implementation of AdamW is deprecated and will be removed in a future version. Use the PyTorch implementation torch.optim.AdamW instead, or set `no_deprecation_warning=True` to disable this warning
#   warnings.warn(
#   0%|          | 0/2103 [00:00<?, ?it/s]
# Epoch 1/3 completed. Loss: 0.1300184279680252
# Epoch 2/3 completed. Loss: 0.806008517742157
# Epoch 3/3 completed. Loss: 0.00026544384309090674
# ('./fine_tuned_bert_model/tokenizer_config.json',
#  './fine_tuned_bert_model/special_tokens_map.json',
#  './fine_tuned_bert_model/vocab.txt',
#  './fine_tuned_bert_model/added_tokens.json')

# %%
import torch
from transformers import BertForSequenceClassification, BertTokenizer
from tqdm import tqdm
import pandas as pd

# Define device
device = torch.device('cuda') if torch.cuda.is_available() else torch.device('cpu')

# Define the directory where the model and tokenizer are saved
model_dir = './fine_tuned_bert_model'

# Load the fine-tuned BERT model
bert_model = BertForSequenceClassification.from_pretrained(model_dir)
bert_model.to(device)
bert_model.eval()

# Load the tokenizer from the same directory
bert_tokenizer = BertTokenizer.from_pretrained(model_dir)

# Access the underlying BERT model for embeddings
bert_base_model = bert_model.bert
bert_base_model.to(device)
bert_base_model.eval()

# Function to get BERT embeddings in batches
max_length = 128
batch_size = 32

def get_bert_embeddings_batch(batch_texts):
    encoded_reviews = bert_tokenizer.batch_encode_plus(
        batch_texts,
        add_special_tokens=True,
        max_length=max_length,
        padding='max_length',
        truncation=True,
        return_attention_mask=True,
        return_tensors='pt'
    )

    input_ids = encoded_reviews['input_ids'].to(device)
    attention_mask = encoded_reviews['attention_mask'].to(device)

    with torch.no_grad():
        outputs = bert_base_model(input_ids, attention_mask=attention_mask)
        cls_embeddings = outputs.last_hidden_state[:, 0, :]  # Shape: [batch_size, hidden_dim]
        return cls_embeddings

# Reload the training data to get the 'cleaned_review' column
train_file_path = '/kaggle/input/sentiment-analysis/DVD11.csv'
train_data_df = pd.read_csv(train_file_path, nrows=20000) # Reload the dataframe

# Ensure 'review_body' is string and handle missing values
train_data_df['review_body'] = train_data_df['review_body'].astype(str).fillna('') # Use the DataFrame here

bert_embeddings = []

# Process in batches
for i in tqdm(range(0, len(train_data_df), batch_size), desc="Extracting BERT embeddings"): # Iterate over the DataFrame
    batch_reviews = train_data_df['review_body'][i:i+batch_size].tolist() #Extract review_body instead of cleaned_review
    embeddings = get_bert_embeddings_batch(batch_reviews)
    bert_embeddings.append(embeddings)

# Concatenate all embeddings
bert_embeddings = torch.cat(bert_embeddings, dim=0)  # Shape: [num_samples, hidden_dim]

# Optionally, convert embeddings to NumPy for further processing
bert_embeddings_np = bert_embeddings.cpu().numpy()

# Print the shape of the embeddings to verify
print(f"BERT Embeddings Shape: {bert_embeddings_np.shape}")
# Out:
# Extracting BERT embeddings:   0%|          | 0/390 [00:00<?, ?it/s]
# Extracting BERT embeddings:   1%|          | 2/390 [00:00<02:28,  2.62it/s]
# Extracting BERT embeddings:   1%|          | 3/390 [00:01<03:18,  1.95it/s]
# Extracting BERT embeddings:   1%|          | 4/390 [00:02<03:39,  1.76it/s]
# Extracting BERT embeddings:   1%|▏         | 5/390 [00:02<03:53,  1.65it/s]
# Extracting BERT embeddings:   2%|▏         | 6/390 [00:03<04:03,  1.57it/s]
# Extracting BERT embeddings:   2%|▏         | 7/390 [00:04<04:08,  1.54it/s]
# Extracting BERT embeddings:   2%|▏         | 8/390 [00:04<04:10,  1.52it/s]
# Extracting BERT embeddings:   2%|▏         | 9/390 [00:05<04:14,  1.50it/s]
# Extracting BERT embeddings:   3%|▎         | 10/390 [00:06<04:15,  1.49it/s]
# Extracting BERT embeddings:   3%|▎         | 11/390 [00:06<04:15,  1.48it/s]
# Extracting BERT embeddings:   3%|▎         | 12/390 [00:07<04:16,  1.48it/s]
# Extracting BERT embeddings:   3%|▎         | 13/390 [00:08<04:16,  1.47it/s]
# Extracting BERT embeddings:   4%|▎         | 14/390 [00:08<04:15,  1.47it/s]
# Extracting BERT embeddings:   4%|▍         | 15/390 [00:09<04:15,  1.47it/s]
# Extracting BERT embeddings:   4%|▍         | 16/390 [00:10<04:15,  1.46it/s]
# Extracting BERT embeddings:   4%|▍         | 17/390 [00:11<04:15,  1.46it/s]
# Extracting BERT embeddings:   5%|▍         | 18/390 [00:11<04:14,  1.46it/s]
# Extracting BERT embeddings:   5%|▍         | 19/390 [00:12<04:14,  1.46it/s]
# Extracting BERT embeddings:   5%|▌         | 20/390 [00:13<04:14,  1.46it/s]
# Extracting BERT embeddings:   5%|▌         | 21/390 [00:13<04:13,  1.45it/s]
# Extracting BERT embeddings:   6%|▌         | 22/390 [00:14<04:13,  1.45it/s]
# Extracting BERT embeddings:   6%|▌         | 23/390 [00:15<04:12,  1.45it/s]
# Extracting BERT embeddings:   6%|▌         | 24/390 [00:15<04:12,  1.45it/s]
# Extracting BERT embeddings:   6%|▋         | 25/390 [00:16<04:11,  1.45it/s]
# Extracting BERT embeddings:   7%|▋         | 26/390 [00:17<04:11,  1.45it/s]
# Extracting BERT embeddings:   7%|▋         | 27/390 [00:17<04:11,  1.45it/s]
# Extracting BERT embeddings:   7%|▋         | 28/390 [00:18<04:10,  1.44it/s]
# Extracting BERT embeddings:   7%|▋         | 29/390 [00:19<04:10,  1.44it/s]
# Extracting BERT embeddings:   8%|▊         | 30/390 [00:20<04:10,  1.44it/s]
# Extracting BERT embeddings:   8%|▊         | 31/390 [00:20<04:09,  1.44it/s]
# Extracting BERT embeddings:   8%|▊         | 32/390 [00:21<04:09,  1.44it/s]
# Extracting BERT embeddings:   8%|▊         | 33/390 [00:22<04:08,  1.44it/s]
# Extracting BERT embeddings:   9%|▊         | 34/390 [00:22<04:08,  1.43it/s]
# Extracting BERT embeddings:   9%|▉         | 35/390 [00:23<04:07,  1.43it/s]
# Extracting BERT embeddings:   9%|▉         | 36/390 [00:24<04:07,  1.43it/s]
# Extracting BERT embeddings:   9%|▉         | 37/390 [00:24<04:06,  1.43it/s]
# Extracting BERT embeddings:  10%|▉         | 38/390 [00:25<04:05,  1.43it/s]
# Extracting BERT embeddings:  10%|█         | 39/390 [00:26<04:05,  1.43it/s]
# Extracting BERT embeddings:  10%|█         | 40/390 [00:26<04:04,  1.43it/s]
# Extracting BERT embeddings:  11%|█         | 41/390 [00:27<04:04,  1.43it/s]
# Extracting BERT embeddings:  11%|█         | 42/390 [00:28<04:03,  1.43it/s]
# Extracting BERT embeddings:  11%|█         | 43/390 [00:29<04:02,  1.43it/s]
# Extracting BERT embeddings:  11%|█▏        | 44/390 [00:29<04:02,  1.43it/s]
# Extracting BERT embeddings:  12%|█▏        | 45/390 [00:30<04:01,  1.43it/s]
# Extracting BERT embeddings:  12%|█▏        | 46/390 [00:31<04:01,  1.42it/s]
# Extracting BERT embeddings:  12%|█▏        | 47/390 [00:31<03:59,  1.43it/s]
# Extracting BERT embeddings:  12%|█▏        | 48/390 [00:32<03:58,  1.43it/s]
# Extracting BERT embeddings:  13%|█▎        | 49/390 [00:33<03:58,  1.43it/s]
# Extracting BERT embeddings:  13%|█▎        | 50/390 [00:33<03:57,  1.43it/s]
# Extracting BERT embeddings:  13%|█▎        | 51/390 [00:34<03:57,  1.43it/s]
# Extracting BERT embeddings:  13%|█▎        | 52/390 [00:35<03:56,  1.43it/s]
# Extracting BERT embeddings:  14%|█▎        | 53/390 [00:36<03:55,  1.43it/s]
# Extracting BERT embeddings:  14%|█▍        | 54/390 [00:36<03:54,  1.43it/s]
# Extracting BERT embeddings:  14%|█▍        | 55/390 [00:37<03:54,  1.43it/s]
# Extracting BERT embeddings:  14%|█▍        | 56/390 [00:38<03:53,  1.43it/s]
# Extracting BERT embeddings:  15%|█▍        | 57/390 [00:38<03:52,  1.43it/s]
# Extracting BERT embeddings:  15%|█▍        | 58/390 [00:39<03:52,  1.43it/s]
# Extracting BERT embeddings:  15%|█▌        | 59/390 [00:40<03:51,  1.43it/s]
# Extracting BERT embeddings:  15%|█▌        | 60/390 [00:40<03:50,  1.43it/s]
# Extracting BERT embeddings:  16%|█▌        | 61/390 [00:41<03:49,  1.43it/s]
# Extracting BERT embeddings:  16%|█▌        | 62/390 [00:42<03:48,  1.43it/s]
# Extracting BERT embeddings:  16%|█▌        | 63/390 [00:43<03:48,  1.43it/s]
# Extracting BERT embeddings:  16%|█▋        | 64/390 [00:43<03:46,  1.44it/s]
# Extracting BERT embeddings:  17%|█▋        | 65/390 [00:44<03:46,  1.44it/s]
# Extracting BERT embeddings:  17%|█▋        | 66/390 [00:45<03:45,  1.43it/s]
# Extracting BERT embeddings:  17%|█▋        | 67/390 [00:45<03:45,  1.43it/s]
# Extracting BERT embeddings:  17%|█▋        | 68/390 [00:46<03:44,  1.44it/s]
# Extracting BERT embeddings:  18%|█▊        | 69/390 [00:47<03:43,  1.43it/s]
# Extracting BERT embeddings:  18%|█▊        | 70/390 [00:47<03:42,  1.44it/s]
# Extracting BERT embeddings:  18%|█▊        | 71/390 [00:48<03:42,  1.43it/s]
# Extracting BERT embeddings:  18%|█▊        | 72/390 [00:49<03:41,  1.43it/s]
# Extracting BERT embeddings:  19%|█▊        | 73/390 [00:50<03:41,  1.43it/s]
# Extracting BERT embeddings:  19%|█▉        | 74/390 [00:50<03:40,  1.44it/s]
# Extracting BERT embeddings:  19%|█▉        | 75/390 [00:51<03:39,  1.44it/s]
# Extracting BERT embeddings:  19%|█▉        | 76/390 [00:52<03:38,  1.44it/s]
# Extracting BERT embeddings:  20%|█▉        | 77/390 [00:52<03:37,  1.44it/s]
# Extracting BERT embeddings:  20%|██        | 78/390 [00:53<03:37,  1.44it/s]
# Extracting BERT embeddings:  20%|██        | 79/390 [00:54<03:36,  1.44it/s]
# Extracting BERT embeddings:  21%|██        | 80/390 [00:54<03:35,  1.44it/s]
# Extracting BERT embeddings:  21%|██        | 81/390 [00:55<03:34,  1.44it/s]
# Extracting BERT embeddings:  21%|██        | 82/390 [00:56<03:33,  1.44it/s]
# Extracting BERT embeddings:  21%|██▏       | 83/390 [00:56<03:32,  1.44it/s]
# Extracting BERT embeddings:  22%|██▏       | 84/390 [00:57<03:32,  1.44it/s]
# Extracting BERT embeddings:  22%|██▏       | 85/390 [00:58<03:31,  1.44it/s]
# Extracting BERT embeddings:  22%|██▏       | 86/390 [00:59<03:30,  1.44it/s]
# Extracting BERT embeddings:  22%|██▏       | 87/390 [00:59<03:29,  1.45it/s]
# Extracting BERT embeddings:  32%|███▏      | 123/390 [01:24<03:03,  1.46it/s]
# Extracting BERT embeddings:  32%|███▏      | 124/390 [01:25<03:02,  1.46it/s]
# Extracting BERT embeddings:  32%|███▏      | 125/390 [01:25<03:02,  1.46it/s]
# Extracting BERT embeddings:  32%|███▏      | 126/390 [01:26<03:01,  1.45it/s]
# Extracting BERT embeddings:  33%|███▎      | 127/390 [01:27<03:00,  1.46it/s]
# Extracting BERT embeddings:  33%|███▎      | 128/390 [01:27<03:00,  1.45it/s]
# Extracting BERT embeddings:  33%|███▎      | 129/390 [01:28<02:59,  1.46it/s]
# Extracting BERT embeddings:  33%|███▎      | 130/390 [01:29<02:58,  1.46it/s]
# Extracting BERT embeddings:  34%|███▎      | 131/390 [01:29<02:58,  1.45it/s]
# Extracting BERT embeddings:  34%|███▍      | 132/390 [01:30<02:57,  1.45it/s]
# Extracting BERT embeddings:  34%|███▍      | 133/390 [01:31<02:56,  1.45it/s]
# Extracting BERT embeddings:  34%|███▍      | 134/390 [01:32<02:55,  1.46it/s]
# Extracting BERT embeddings:  35%|███▍      | 135/390 [01:32<02:55,  1.45it/s]
# Extracting BERT embeddings:  35%|███▍      | 136/390 [01:33<02:54,  1.45it/s]
# Extracting BERT embeddings:  35%|███▌      | 137/390 [01:34<02:54,  1.45it/s]
# Extracting BERT embeddings:  35%|███▌      | 138/390 [01:34<02:53,  1.45it/s]
# Extracting BERT embeddings:  36%|███▌      | 139/390 [01:35<02:52,  1.45it/s]
# Extracting BERT embeddings:  36%|███▌      | 140/390 [01:36<02:52,  1.45it/s]
# Extracting BERT embeddings:  36%|███▌      | 141/390 [01:36<02:51,  1.45it/s]
# Extracting BERT embeddings:  36%|███▋      | 142/390 [01:37<02:51,  1.45it/s]
# Extracting BERT embeddings:  37%|███▋      | 143/390 [01:38<02:50,  1.45it/s]
# Extracting BERT embeddings:  37%|███▋      | 144/390 [01:38<02:49,  1.45it/s]
# Extracting BERT embeddings:  37%|███▋      | 145/390 [01:39<02:48,  1.45it/s]
# Extracting BERT embeddings:  37%|███▋      | 146/390 [01:40<02:48,  1.45it/s]
# Extracting BERT embeddings:  38%|███▊      | 147/390 [01:41<02:48,  1.45it/s]
# Extracting BERT embeddings:  38%|███▊      | 148/390 [01:41<02:47,  1.45it/s]
# Extracting BERT embeddings:  38%|███▊      | 149/390 [01:42<02:46,  1.45it/s]
# Extracting BERT embeddings:  38%|███▊      | 150/390 [01:43<02:45,  1.45it/s]
# Extracting BERT embeddings:  39%|███▊      | 151/390 [01:43<02:44,  1.45it/s]
# Extracting BERT embeddings:  39%|███▉      | 152/390 [01:44<02:44,  1.45it/s]
# Extracting BERT embeddings:  39%|███▉      | 153/390 [01:45<02:43,  1.45it/s]
# Extracting BERT embeddings:  39%|███▉      | 154/390 [01:45<02:43,  1.45it/s]
# Extracting BERT embeddings:  40%|███▉      | 155/390 [01:46<02:42,  1.45it/s]
# Extracting BERT embeddings:  40%|████      | 156/390 [01:47<02:41,  1.45it/s]
# Extracting BERT embeddings:  40%|████      | 157/390 [01:47<02:41,  1.45it/s]
# Extracting BERT embeddings:  49%|████▉     | 192/390 [02:12<02:17,  1.44it/s]
# Extracting BERT embeddings:  49%|████▉     | 193/390 [02:12<02:16,  1.44it/s]
# Extracting BERT embeddings:  50%|████▉     | 194/390 [02:13<02:15,  1.44it/s]
# Extracting BERT embeddings:  50%|█████     | 195/390 [02:14<02:15,  1.44it/s]
# Extracting BERT embeddings:  50%|█████     | 196/390 [02:14<02:14,  1.44it/s]
# Extracting BERT embeddings:  51%|█████     | 197/390 [02:15<02:13,  1.45it/s]
# Extracting BERT embeddings:  51%|█████     | 198/390 [02:16<02:12,  1.44it/s]
# Extracting BERT embeddings:  51%|█████     | 199/390 [02:17<02:12,  1.45it/s]
# Extracting BERT embeddings:  51%|█████▏    | 200/390 [02:17<02:11,  1.45it/s]
# Extracting BERT embeddings:  52%|█████▏    | 201/390 [02:18<02:10,  1.45it/s]
# Extracting BERT embeddings:  52%|█████▏    | 202/390 [02:19<02:09,  1.45it/s]
# Extracting BERT embeddings:  52%|█████▏    | 203/390 [02:19<02:09,  1.45it/s]
# Extracting BERT embeddings:  52%|█████▏    | 204/390 [02:20<02:08,  1.45it/s]
# Extracting BERT embeddings:  53%|█████▎    | 205/390 [02:21<02:08,  1.44it/s]
# Extracting BERT embeddings:  53%|█████▎    | 206/390 [02:21<02:06,  1.45it/s]
# Extracting BERT embeddings:  53%|█████▎    | 207/390 [02:22<02:06,  1.45it/s]
# Extracting BERT embeddings:  53%|█████▎    | 208/390 [02:23<02:05,  1.45it/s]
# Extracting BERT embeddings:  54%|█████▎    | 209/390 [02:23<02:04,  1.45it/s]
# Extracting BERT embeddings:  54%|█████▍    | 210/390 [02:24<02:04,  1.45it/s]
# Extracting BERT embeddings:  54%|█████▍    | 211/390 [02:25<02:03,  1.45it/s]
# Extracting BERT embeddings:  54%|█████▍    | 212/390 [02:26<02:02,  1.45it/s]
# Extracting BERT embeddings:  55%|█████▍    | 213/390 [02:26<02:02,  1.45it/s]
# Extracting BERT embeddings:  55%|█████▍    | 214/390 [02:27<02:01,  1.45it/s]
# Extracting BERT embeddings:  55%|█████▌    | 215/390 [02:28<02:00,  1.45it/s]
# Extracting BERT embeddings:  55%|█████▌    | 216/390 [02:28<02:00,  1.45it/s]
# Extracting BERT embeddings:  56%|█████▌    | 217/390 [02:29<01:59,  1.45it/s]
# Extracting BERT embeddings:  56%|█████▌    | 218/390 [02:30<01:58,  1.45it/s]
# Extracting BERT embeddings:  56%|█████▌    | 219/390 [02:30<01:57,  1.45it/s]
# Extracting BERT embeddings:  56%|█████▋    | 220/390 [02:31<01:57,  1.45it/s]
# Extracting BERT embeddings:  57%|█████▋    | 221/390 [02:32<01:56,  1.45it/s]
# Extracting BERT embeddings:  57%|█████▋    | 222/390 [02:32<01:55,  1.45it/s]
# Extracting BERT embeddings:  57%|█████▋    | 223/390 [02:33<01:55,  1.45it/s]
# Extracting BERT embeddings:  57%|█████▋    | 224/390 [02:34<01:54,  1.45it/s]
# Extracting BERT embeddings:  58%|█████▊    | 225/390 [02:34<01:53,  1.45it/s]
# Extracting BERT embeddings:  84%|████████▍ | 329/390 [03:46<00:42,  1.45it/s]
# Extracting BERT embeddings:  85%|████████▍ | 330/390 [03:47<00:41,  1.45it/s]
# Extracting BERT embeddings:  85%|████████▍ | 331/390 [03:47<00:40,  1.45it/s]
# Extracting BERT embeddings:  85%|████████▌ | 332/390 [03:48<00:39,  1.45it/s]
# Extracting BERT embeddings:  85%|████████▌ | 333/390 [03:49<00:39,  1.45it/s]
# Extracting BERT embeddings:  86%|████████▌ | 334/390 [03:49<00:38,  1.45it/s]
# Extracting BERT embeddings:  86%|████████▌ | 335/390 [03:50<00:37,  1.45it/s]
# Extracting BERT embeddings:  86%|████████▌ | 336/390 [03:51<00:37,  1.45it/s]
# Extracting BERT embeddings:  86%|████████▋ | 337/390 [03:52<00:36,  1.45it/s]
# Extracting BERT embeddings:  87%|████████▋ | 338/390 [03:52<00:35,  1.45it/s]
# Extracting BERT embeddings:  87%|████████▋ | 339/390 [03:53<00:35,  1.45it/s]
# Extracting BERT embeddings:  87%|████████▋ | 340/390 [03:54<00:34,  1.45it/s]
# Extracting BERT embeddings:  87%|████████▋ | 341/390 [03:54<00:33,  1.45it/s]
# Extracting BERT embeddings:  88%|████████▊ | 342/390 [03:55<00:33,  1.45it/s]
# Extracting BERT embeddings:  88%|████████▊ | 343/390 [03:56<00:32,  1.45it/s]
# Extracting BERT embeddings:  88%|████████▊ | 344/390 [03:56<00:31,  1.45it/s]
# Extracting BERT embeddings:  88%|████████▊ | 345/390 [03:57<00:30,  1.45it/s]
# Extracting BERT embeddings:  89%|████████▊ | 346/390 [03:58<00:30,  1.45it/s]
# Extracting BERT embeddings:  89%|████████▉ | 347/390 [03:58<00:29,  1.46it/s]
# Extracting BERT embeddings:  89%|████████▉ | 348/390 [03:59<00:28,  1.46it/s]
# Extracting BERT embeddings:  89%|████████▉ | 349/390 [04:00<00:28,  1.45it/s]
# Extracting BERT embeddings:  90%|████████▉ | 350/390 [04:00<00:27,  1.45it/s]
# Extracting BERT embeddings:  90%|█████████ | 351/390 [04:01<00:26,  1.45it/s]
# Extracting BERT embeddings:  90%|█████████ | 352/390 [04:02<00:26,  1.45it/s]
# Extracting BERT embeddings:  91%|█████████ | 353/390 [04:03<00:25,  1.45it/s]
# Extracting BERT embeddings:  91%|█████████ | 354/390 [04:03<00:24,  1.45it/s]
# Extracting BERT embeddings:  91%|█████████ | 355/390 [04:04<00:24,  1.45it/s]
# Extracting BERT embeddings:  91%|█████████▏| 356/390 [04:05<00:23,  1.46it/s]
# Extracting BERT embeddings:  92%|█████████▏| 357/390 [04:05<00:22,  1.46it/s]
# Extracting BERT embeddings:  92%|█████████▏| 358/390 [04:06<00:21,  1.46it/s]
# Extracting BERT embeddings:  92%|█████████▏| 359/390 [04:07<00:21,  1.46it/s]
# Extracting BERT embeddings:  92%|█████████▏| 360/390 [04:07<00:20,  1.46it/s]
# Extracting BERT embeddings:  93%|█████████▎| 361/390 [04:08<00:19,  1.46it/s]
# Extracting BERT embeddings:  93%|█████████▎| 362/390 [04:09<00:19,  1.45it/s]
# Extracting BERT embeddings:  93%|█████████▎| 363/390 [04:09<00:18,  1.45it/s]
# Extracting BERT embeddings:  93%|█████████▎| 364/390 [04:10<00:17,  1.45it/s]
# Extracting BERT embeddings:  94%|█████████▎| 365/390 [04:11<00:17,  1.45it/s]
# Extracting BERT embeddings:  94%|█████████▍| 366/390 [04:11<00:16,  1.45it/s]
# Extracting BERT embeddings:  94%|█████████▍| 367/390 [04:12<00:15,  1.45it/s]
# Extracting BERT embeddings:  94%|█████████▍| 368/390 [04:13<00:15,  1.45it/s]
# Extracting BERT embeddings:  95%|█████████▍| 369/390 [04:14<00:14,  1.45it/s]
# Extracting BERT embeddings:  95%|█████████▍| 370/390 [04:14<00:13,  1.45it/s]
# Extracting BERT embeddings:  95%|█████████▌| 371/390 [04:15<00:13,  1.45it/s]
# Extracting BERT embeddings:  95%|█████████▌| 372/390 [04:16<00:12,  1.45it/s]
# Extracting BERT embeddings:  96%|█████████▌| 373/390 [04:16<00:11,  1.45it/s]
# Extracting BERT embeddings:  96%|█████████▌| 374/390 [04:17<00:11,  1.45it/s]
# Extracting BERT embeddings:  96%|█████████▌| 375/390 [04:18<00:10,  1.45it/s]
# Extracting BERT embeddings:  96%|█████████▋| 376/390 [04:18<00:09,  1.45it/s]
# Extracting BERT embeddings:  97%|█████████▋| 377/390 [04:19<00:08,  1.45it/s]
# Extracting BERT embeddings:  97%|█████████▋| 378/390 [04:20<00:08,  1.45it/s]
# Extracting BERT embeddings:  97%|█████████▋| 379/390 [04:20<00:07,  1.45it/s]
# Extracting BERT embeddings:  97%|█████████▋| 380/390 [04:21<00:06,  1.45it/s]
# Extracting BERT embeddings:  98%|█████████▊| 381/390 [04:22<00:06,  1.45it/s]
# Extracting BERT embeddings:  98%|█████████▊| 382/390 [04:23<00:05,  1.45it/s]
# Extracting BERT embeddings:  98%|█████████▊| 383/390 [04:23<00:04,  1.45it/s]
# Extracting BERT embeddings:  98%|█████████▊| 384/390 [04:24<00:04,  1.45it/s]
# Extracting BERT embeddings:  99%|█████████▊| 385/390 [04:25<00:03,  1.45it/s]
# Extracting BERT embeddings:  99%|█████████▉| 386/390 [04:25<00:02,  1.45it/s]
# Extracting BERT embeddings:  99%|█████████▉| 387/390 [04:26<00:02,  1.44it/s]
# Extracting BERT embeddings:  99%|█████████▉| 388/390 [04:27<00:01,  1.45it/s]
# Extracting BERT embeddings: 100%|█████████▉| 389/390 [04:27<00:00,  1.45it/s]
# Extracting BERT embeddings: 100%|██████████| 390/390 [04:28<00:00,  1.45it/s]
# BERT Embeddings Shape: (12450, 1024)

# %%
# Convert BERT embeddings to NumPy for SVM
bert_embeddings_np = bert_embeddings.cpu().numpy()
labels = train_data_df['star_rating'].values # Use train_data_df to access the star_rating column

# Split data into training and validation sets
train_inputs, val_inputs, train_labels, val_labels = train_test_split(
    bert_embeddings_np, labels, test_size=0.1, random_state=42
)

# %%
from sklearn.svm import SVC
from sklearn.preprocessing import StandardScaler
from sklearn.pipeline import make_pipeline

# Initialize SVM with standard scaling
svm_classifier = make_pipeline(StandardScaler(), SVC(kernel='linear', C=1.0))

# Train the SVM classifier
svm_classifier.fit(train_inputs, train_labels)
# Out:
# Pipeline(steps=[('standardscaler', StandardScaler()),
#                 ('svc', SVC(kernel='linear'))])

# %%
from sklearn.svm import SVC
from sklearn.preprocessing import StandardScaler
from sklearn.pipeline import make_pipeline
from sklearn.metrics import accuracy_score, precision_score, recall_score, f1_score # Import the necessary functions from sklearn.metrics

# Initialize SVM with standard scaling
svm_classifier = make_pipeline(StandardScaler(), SVC(kernel='linear', C=1.0))

# Train the SVM classifier
svm_classifier.fit(train_inputs, train_labels)

# Make predictions on the validation set
val_preds = svm_classifier.predict(val_inputs)

# Calculate metrics for validation set
accuracy = accuracy_score(val_labels, val_preds)
precision = precision_score(val_labels, val_preds, average='macro')
recall = recall_score(val_labels, val_preds, average='macro')
f1 = f1_score(val_labels, val_preds, average='macro')

# Print metrics
print(f"Accuracy: {accuracy:.2f}, Precision: {precision:.2f}, Recall: {recall:.2f}, F1-score: {f1:.2f}")
# Out:
# Accuracy: 0.96, Precision: 0.91, Recall: 0.91, F1-score: 0.91

# %%
import pandas as pd
import torch
from torch.utils.data import DataLoader, Dataset
from sklearn.metrics import accuracy_score, precision_score, recall_score, f1_score
from tqdm import tqdm

# Assuming you have already defined get_bert_embeddings_batch and loaded bert_base_model and svm_classifier

# Define a custom Dataset
class ReviewDataset(Dataset):
    def __init__(self, reviews):
        self.reviews = reviews

    def __len__(self):
        return len(self.reviews)

    def __getitem__(self, idx):
        return self.reviews[idx]

# Load test data
test_file_path = '/kaggle/input/sentiment-analysis/Books11.csv'  # Replace with your test file path
test_data = pd.read_csv(test_file_path, nrows=20000)

# Clean the test data
test_data = test_data.dropna(subset=['review_body'])

# Prepare DataLoader with a suitable batch size
batch_size = 32  # Adjust based on your GPU memory
dataset = ReviewDataset(test_data['review_body'].tolist())
dataloader = DataLoader(dataset, batch_size=batch_size, shuffle=False)

test_embeddings = []
device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')

bert_base_model.to(device)
bert_base_model.eval()  # Set model to evaluation mode

with torch.no_grad():
    for batch in tqdm(dataloader, desc="Processing Batches"):
        # Get embeddings
        embeddings = get_bert_embeddings_batch(batch)  # Ensure this function handles batch inputs
        # Move embeddings to CPU
        embeddings = embeddings.cpu()
        test_embeddings.append(embeddings)
        # Optional: Clear cache to free up GPU memory
        torch.cuda.empty_cache()

# Concatenate all embeddings
test_embeddings = torch.cat(test_embeddings, dim=0)  # Shape: [num_samples, hidden_dim]
test_embeddings_np = test_embeddings.numpy()

# Use existing sentiment labels for the test set
test_labels = test_data['star_rating'].values

# Make predictions on the test set
test_preds = svm_classifier.predict(test_embeddings_np)

# Calculate metrics for test set
accuracy = accuracy_score(test_labels, test_preds)
precision = precision_score(test_labels, test_preds, average='macro')
recall = recall_score(test_labels, test_preds, average='macro')
f1 = f1_score(test_labels, test_preds, average='macro')

# Print metrics
print(f"Test Accuracy: {accuracy:.2f}, Test Precision: {precision:.2f}, Test Recall: {recall:.2f}, Test F1-score: {f1:.2f}")
# Out:
# Processing Batches:   0%|          | 0/625 [00:00<?, ?it/s]
# Processing Batches:   0%|          | 1/625 [00:01<10:35,  1.02s/it]
# Processing Batches:   0%|          | 2/625 [00:01<09:45,  1.06it/s]
# Processing Batches:   0%|          | 3/625 [00:02<09:10,  1.13it/s]
# Processing Batches:   1%|          | 4/625 [00:03<08:53,  1.16it/s]
# Processing Batches:   1%|          | 5/625 [00:04<08:49,  1.17it/s]
# Processing Batches:   1%|          | 6/625 [00:05<08:50,  1.17it/s]
# Processing Batches:   1%|          | 7/625 [00:06<08:49,  1.17it/s]
# Processing Batches:  82%|████████▏ | 513/625 [07:06<01:33,  1.20it/s]
# Processing Batches:  82%|████████▏ | 514/625 [07:06<01:33,  1.19it/s]
# Processing Batches:  82%|████████▏ | 515/625 [07:07<01:31,  1.20it/s]
# Processing Batches:  83%|████████▎ | 516/625 [07:08<01:29,  1.22it/s]
# Processing Batches:  83%|████████▎ | 517/625 [07:09<01:30,  1.19it/s]
# Processing Batches:  83%|████████▎ | 518/625 [07:10<01:32,  1.15it/s]
# Processing Batches:  83%|████████▎ | 519/625 [07:11<01:32,  1.15it/s]
# Processing Batches:  83%|████████▎ | 520/625 [07:12<01:30,  1.17it/s]
# Processing Batches:  83%|████████▎ | 521/625 [07:12<01:28,  1.17it/s]
# Processing Batches:  84%|████████▎ | 522/625 [07:13<01:29,  1.15it/s]
# Processing Batches:  84%|████████▎ | 523/625 [07:14<01:26,  1.18it/s]
# Processing Batches:  84%|████████▍ | 524/625 [07:15<01:23,  1.20it/s]
# Processing Batches:  84%|████████▍ | 525/625 [07:16<01:22,  1.21it/s]
# Processing Batches:  84%|████████▍ | 526/625 [07:17<01:20,  1.22it/s]
# Processing Batches:  84%|████████▍ | 527/625 [07:17<01:20,  1.22it/s]
# Processing Batches:  84%|████████▍ | 528/625 [07:18<01:20,  1.21it/s]
# Processing Batches:  85%|████████▍ | 529/625 [07:19<01:19,  1.20it/s]
# Processing Batches:  85%|████████▍ | 530/625 [07:20<01:19,  1.19it/s]
# Processing Batches:  85%|████████▍ | 531/625 [07:21<01:17,  1.21it/s]
# Processing Batches:  85%|████████▌ | 532/625 [07:21<01:15,  1.23it/s]
# Processing Batches:  85%|████████▌ | 533/625 [07:22<01:14,  1.24it/s]
# Processing Batches:  85%|████████▌ | 534/625 [07:23<01:14,  1.22it/s]
# Processing Batches:  86%|████████▌ | 535/625 [07:24<01:13,  1.23it/s]
# Processing Batches:  86%|████████▌ | 536/625 [07:25<01:12,  1.23it/s]
# Processing Batches:  86%|████████▌ | 537/625 [07:25<01:10,  1.25it/s]
# Processing Batches:  86%|████████▌ | 538/625 [07:26<01:09,  1.24it/s]
# Processing Batches:  86%|████████▌ | 539/625 [07:27<01:10,  1.22it/s]
# Processing Batches:  86%|████████▋ | 540/625 [07:28<01:08,  1.24it/s]
# Processing Batches:  87%|████████▋ | 541/625 [07:29<01:09,  1.21it/s]
# Processing Batches:  87%|████████▋ | 542/625 [07:30<01:08,  1.20it/s]
# Processing Batches:  87%|████████▋ | 543/625 [07:30<01:07,  1.21it/s]
# Processing Batches:  87%|████████▋ | 544/625 [07:31<01:08,  1.19it/s]
# Processing Batches:  87%|████████▋ | 545/625 [07:32<01:06,  1.20it/s]
# Processing Batches:  87%|████████▋ | 546/625 [07:33<01:06,  1.20it/s]
# Processing Batches:  88%|████████▊ | 547/625 [07:34<01:04,  1.22it/s]
# Processing Batches:  88%|████████▊ | 548/625 [07:35<01:02,  1.22it/s]
# Processing Batches:  88%|████████▊ | 549/625 [07:35<01:01,  1.23it/s]
# Processing Batches:  88%|████████▊ | 550/625 [07:36<01:01,  1.22it/s]
# Processing Batches:  88%|████████▊ | 551/625 [07:37<01:02,  1.19it/s]
# Processing Batches:  88%|████████▊ | 552/625 [07:38<01:01,  1.19it/s]
# Processing Batches:  88%|████████▊ | 553/625 [07:39<01:01,  1.18it/s]
# Processing Batches:  89%|████████▊ | 554/625 [07:40<01:02,  1.14it/s]
# Processing Batches:  89%|████████▉ | 555/625 [07:41<01:01,  1.14it/s]
# Processing Batches:  89%|████████▉ | 556/625 [07:41<00:59,  1.16it/s]
# Processing Batches:  89%|████████▉ | 557/625 [07:42<00:57,  1.18it/s]
# Processing Batches:  89%|████████▉ | 558/625 [07:43<00:56,  1.18it/s]
# Processing Batches:  89%|████████▉ | 559/625 [07:44<00:56,  1.16it/s]
# Processing Batches:  90%|████████▉ | 560/625 [07:45<00:56,  1.16it/s]
# Processing Batches:  90%|████████▉ | 561/625 [07:46<00:54,  1.17it/s]
# Processing Batches:  90%|████████▉ | 562/625 [07:47<00:53,  1.17it/s]
# Processing Batches:  90%|█████████ | 563/625 [07:47<00:52,  1.19it/s]
# Processing Batches:  90%|█████████ | 564/625 [07:48<00:51,  1.19it/s]
# Processing Batches:  90%|█████████ | 565/625 [07:49<00:50,  1.19it/s]
# Processing Batches:  91%|█████████ | 566/625 [07:50<00:49,  1.20it/s]
# Processing Batches:  91%|█████████ | 567/625 [07:51<00:48,  1.19it/s]
# Processing Batches:  91%|█████████ | 568/625 [07:52<00:47,  1.19it/s]
# Processing Batches:  91%|█████████ | 569/625 [07:52<00:47,  1.19it/s]
# Processing Batches:  91%|█████████ | 570/625 [07:53<00:45,  1.21it/s]
# Processing Batches:  91%|█████████▏| 571/625 [07:54<00:44,  1.21it/s]
# Processing Batches:  92%|█████████▏| 572/625 [07:55<00:44,  1.19it/s]
# Processing Batches:  92%|█████████▏| 573/625 [07:56<00:44,  1.17it/s]
# Processing Batches:  92%|█████████▏| 574/625 [07:57<00:43,  1.17it/s]
# Processing Batches:  92%|█████████▏| 575/625 [07:57<00:41,  1.20it/s]
# Processing Batches:  92%|█████████▏| 576/625 [07:58<00:40,  1.21it/s]
# Processing Batches:  92%|█████████▏| 577/625 [07:59<00:39,  1.21it/s]
# Processing Batches:  92%|█████████▏| 578/625 [08:00<00:39,  1.19it/s]
# Processing Batches:  93%|█████████▎| 579/625 [08:01<00:38,  1.20it/s]
# Processing Batches:  93%|█████████▎| 580/625 [08:02<00:36,  1.22it/s]
# Processing Batches:  93%|█████████▎| 581/625 [08:02<00:37,  1.18it/s]
# Processing Batches:  93%|█████████▎| 582/625 [08:03<00:35,  1.19it/s]
# Processing Batches:  93%|█████████▎| 583/625 [08:04<00:35,  1.20it/s]
# Processing Batches:  93%|█████████▎| 584/625 [08:05<00:33,  1.21it/s]
# Processing Batches:  94%|█████████▎| 585/625 [08:06<00:33,  1.20it/s]
# Processing Batches:  94%|█████████▍| 586/625 [08:07<00:32,  1.20it/s]
# Processing Batches:  94%|█████████▍| 587/625 [08:07<00:31,  1.20it/s]
# Processing Batches:  94%|█████████▍| 588/625 [08:08<00:30,  1.21it/s]
# Processing Batches:  94%|█████████▍| 589/625 [08:09<00:29,  1.21it/s]
# Processing Batches:  94%|█████████▍| 590/625 [08:10<00:30,  1.13it/s]
# Processing Batches:  95%|█████████▍| 591/625 [08:11<00:29,  1.14it/s]
# Processing Batches:  95%|█████████▍| 592/625 [08:12<00:28,  1.15it/s]
# Processing Batches:  95%|█████████▍| 593/625 [08:13<00:28,  1.11it/s]
# Processing Batches:  95%|█████████▌| 594/625 [08:14<00:27,  1.11it/s]
# Processing Batches:  95%|█████████▌| 595/625 [08:15<00:26,  1.12it/s]
# Processing Batches:  95%|█████████▌| 596/625 [08:15<00:25,  1.14it/s]
# Processing Batches:  96%|█████████▌| 597/625 [08:16<00:24,  1.15it/s]
# Processing Batches:  96%|█████████▌| 598/625 [08:17<00:23,  1.16it/s]
# Processing Batches:  96%|█████████▌| 599/625 [08:18<00:22,  1.16it/s]
# Processing Batches:  96%|█████████▌| 600/625 [08:19<00:21,  1.17it/s]
# Processing Batches:  96%|█████████▌| 601/625 [08:20<00:21,  1.13it/s]
# Processing Batches:  96%|█████████▋| 602/625 [08:21<00:20,  1.13it/s]
# Processing Batches:  96%|█████████▋| 603/625 [08:22<00:19,  1.11it/s]
# Processing Batches:  97%|█████████▋| 604/625 [08:22<00:18,  1.12it/s]
# Processing Batches:  97%|█████████▋| 605/625 [08:23<00:17,  1.13it/s]
# Processing Batches:  97%|█████████▋| 606/625 [08:24<00:16,  1.15it/s]
# Processing Batches:  97%|█████████▋| 607/625 [08:25<00:15,  1.13it/s]
# Processing Batches:  97%|█████████▋| 608/625 [08:26<00:15,  1.12it/s]
# Processing Batches:  97%|█████████▋| 609/625 [08:27<00:14,  1.13it/s]
# Processing Batches:  98%|█████████▊| 610/625 [08:28<00:13,  1.12it/s]
# Processing Batches:  98%|█████████▊| 611/625 [08:29<00:12,  1.13it/s]
# Processing Batches:  98%|█████████▊| 612/625 [08:30<00:11,  1.11it/s]
# Processing Batches:  98%|█████████▊| 613/625 [08:30<00:10,  1.13it/s]
# Processing Batches:  98%|█████████▊| 614/625 [08:31<00:09,  1.16it/s]
# Processing Batches:  98%|█████████▊| 615/625 [08:32<00:08,  1.15it/s]
# Processing Batches:  99%|█████████▊| 616/625 [08:33<00:07,  1.19it/s]
# Processing Batches:  99%|█████████▊| 617/625 [08:34<00:06,  1.18it/s]
# Processing Batches:  99%|█████████▉| 618/625 [08:35<00:05,  1.19it/s]
# Processing Batches:  99%|█████████▉| 619/625 [08:35<00:05,  1.18it/s]
# Processing Batches:  99%|█████████▉| 620/625 [08:36<00:04,  1.18it/s]
# Processing Batches:  99%|█████████▉| 621/625 [08:37<00:03,  1.20it/s]
# Processing Batches: 100%|█████████▉| 622/625 [08:38<00:02,  1.19it/s]
# Processing Batches: 100%|█████████▉| 623/625 [08:39<00:01,  1.17it/s]
# Processing Batches: 100%|█████████▉| 624/625 [08:40<00:00,  1.17it/s]
# Processing Batches: 100%|██████████| 625/625 [08:41<00:00,  1.20it/s]
# Test Accuracy: 0.87, Test Precision: 0.69, Test Recall: 0.70, Test F1-score: 0.69
